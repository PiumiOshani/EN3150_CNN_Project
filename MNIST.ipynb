# %% [markdown]
# <a href="https://colab.research.google.com/github/PiumiOshani/EN3150_CNN_Project/blob/main/MNIST.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch, torch.nn as nn, torch.nn.functional as F, torch.optim as optim
from torch.utils.data import random_split, DataLoader, Subset
from torchvision import datasets, transforms, models
import matplotlib.pyplot as plt
import numpy as np, pandas as pd, seaborn as sns, os
from sklearn.metrics import confusion_matrix, classification_report, precision_score, recall_score

transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.1307,), (0.3081,))
])
mnist_train_full = datasets.MNIST(root="./data", train=True, download=True, transform=transform)
mnist_test_full  = datasets.MNIST(root="./data", train=False, download=True, transform=transform)

# Combine train + test then re-split 70/15/15
full_dataset = torch.utils.data.ConcatDataset([mnist_train_full, mnist_test_full])
n_total = len(full_dataset)
n_train = int(0.70 * n_total)
n_val   = int(0.15 * n_total)
n_test  = n_total - n_train - n_val
train_set, val_set, test_set = random_split(full_dataset, [n_train, n_val, n_test])

batch_size = 128
train_loader = DataLoader(train_set, batch_size=batch_size, shuffle=True)
val_loader   = DataLoader(val_set, batch_size=batch_size, shuffle=False)
test_loader  = DataLoader(test_set, batch_size=batch_size, shuffle=False)

# Define Custom CNN
class SimpleCNN(nn.Module):
    def __init__(self):
        super(SimpleCNN, self).__init__()
        self.conv1 = nn.Conv2d(1, 32, 3, padding=1)
        self.conv2 = nn.Conv2d(32, 64, 3, padding=1)
        self.pool  = nn.MaxPool2d(2,2)
        self.fc1   = nn.Linear(64*7*7, 128)
        self.drop  = nn.Dropout(0.5)
        self.fc2   = nn.Linear(128, 10)
    def forward(self, x):
        x = F.relu(self.conv1(x))
        x = self.pool(x)
        x = self.pool(F.relu(self.conv2(x)))
        x = x.view(-1, 64*7*7)
        x = F.relu(self.fc1(x))
        x = self.drop(x)
        x = self.fc2(x)
        return x

# Training utilities
def train_model(model, optimizer, criterion, train_loader, val_loader, epochs=20):
    history = {'train_loss':[], 'val_loss':[], 'train_acc':[], 'val_acc':[]}
    for ep in range(epochs):
        model.train()
        correct, total, running_loss = 0,0,0
        for x, y in train_loader:
            optimizer.zero_grad()
            out = model(x)
            loss = criterion(out,y)
            loss.backward()
            optimizer.step()
            running_loss += loss.item()
            pred = out.argmax(1)
            correct += (pred==y).sum().item(); total += y.size(0)
        train_loss = running_loss/len(train_loader)
        train_acc  = correct/total
        # validation
        model.eval(); v_correct,v_total,v_loss=0,0,0
        with torch.no_grad():
            for x,y in val_loader:
                out = model(x)
                loss = criterion(out,y)
                v_loss += loss.item()
                pred = out.argmax(1)
                v_correct += (pred==y).sum().item(); v_total += y.size(0)
        val_loss = v_loss/len(val_loader); val_acc = v_correct/v_total
        history['train_loss'].append(train_loss)
        history['val_loss'].append(val_loss)
        history['train_acc'].append(train_acc)
        history['val_acc'].append(val_acc)
        print(f"Epoch {ep+1:02d}: train_loss={train_loss:.4f} val_loss={val_loss:.4f} train_acc={train_acc:.4f} val_acc={val_acc:.4f}")
    return history

  # Evaluation utilities
def evaluate_model(model, loader, criterion, name="Model"):
    model.eval()
    preds, labels = [], []
    total_loss=0
    with torch.no_grad():
        for x,y in loader:
            out=model(x)
            total_loss+=criterion(out,y).item()
            preds.extend(out.argmax(1).numpy())
            labels.extend(y.numpy())
    avg_loss = total_loss/len(loader)
    acc = np.mean(np.array(preds)==np.array(labels))
    print(f"\n{name} Test Accuracy: {acc:.4f}")
    print(classification_report(labels, preds, digits=4))
    cm = confusion_matrix(labels,preds)
    sns.heatmap(cm,annot=True,fmt="d"); plt.title(f"{name} Confusion Matrix"); plt.show()
    return acc, cm, labels, preds

def plot_history(hist, title):
    plt.figure(figsize=(12,4))
    plt.subplot(1,2,1); plt.plot(hist['train_loss'],label='train'); plt.plot(hist['val_loss'],label='val'); plt.title(title+" Loss"); plt.legend()
    plt.subplot(1,2,2); plt.plot(hist['train_acc'],label='train'); plt.plot(hist['val_acc'],label='val'); plt.title(title+" Accuracy"); plt.legend()
    plt.show()

# Train Custom CNN with Adam, SGD, SGD+Momentum
criterion = nn.CrossEntropyLoss()
optimizers_cfg = {
    'adam': lambda m: optim.Adam(m.parameters(), lr=1e-3),
    'sgd':  lambda m: optim.SGD(m.parameters(), lr=0.01),
    'sgd_mom': lambda m: optim.SGD(m.parameters(), lr=0.01, momentum=0.9)
}

results=[]
for name,opt_fn in optimizers_cfg.items():
    print(f"\n===== Training with {name.upper()} =====")
    model = SimpleCNN()
    optimizer = opt_fn(model)
    hist = train_model(model, optimizer, criterion, train_loader, val_loader, epochs=20)
    plot_history(hist, f"Custom CNN ({name})")
    acc,cm,ytrue,ypred = evaluate_model(model, test_loader, criterion, name=f"Custom CNN ({name})")
    results.append({'optimizer':name,'accuracy':acc})

print("\nOptimizer comparison summary:")
print(pd.DataFrame(results))
# Out:
# 100%|██████████| 9.91M/9.91M [00:00<00:00, 19.8MB/s]
# 100%|██████████| 28.9k/28.9k [00:00<00:00, 483kB/s]
# 100%|██████████| 1.65M/1.65M [00:00<00:00, 4.51MB/s]
# 100%|██████████| 4.54k/4.54k [00:00<00:00, 10.3MB/s]
# ===== Training with ADAM =====
# Epoch 01: train_loss=0.2996 val_loss=0.0662 train_acc=0.9072 val_acc=0.9797
# Epoch 02: train_loss=0.0987 val_loss=0.0482 train_acc=0.9709 val_acc=0.9847
# Epoch 03: train_loss=0.0753 val_loss=0.0360 train_acc=0.9778 val_acc=0.9891
# Epoch 04: train_loss=0.0597 val_loss=0.0314 train_acc=0.9819 val_acc=0.9908
# Epoch 05: train_loss=0.0501 val_loss=0.0346 train_acc=0.9845 val_acc=0.9896
# Epoch 06: train_loss=0.0427 val_loss=0.0283 train_acc=0.9871 val_acc=0.9917
# Epoch 07: train_loss=0.0357 val_loss=0.0305 train_acc=0.9890 val_acc=0.9915
# Epoch 08: train_loss=0.0331 val_loss=0.0309 train_acc=0.9896 val_acc=0.9914
# Epoch 09: train_loss=0.0309 val_loss=0.0290 train_acc=0.9898 val_acc=0.9923
# Epoch 10: train_loss=0.0295 val_loss=0.0304 train_acc=0.9907 val_acc=0.9921
# Epoch 11: train_loss=0.0239 val_loss=0.0332 train_acc=0.9921 val_acc=0.9911
# Epoch 12: train_loss=0.0246 val_loss=0.0339 train_acc=0.9919 val_acc=0.9912
# Epoch 13: train_loss=0.0226 val_loss=0.0287 train_acc=0.9926 val_acc=0.9925
# Epoch 14: train_loss=0.0203 val_loss=0.0305 train_acc=0.9935 val_acc=0.9921
# Epoch 15: train_loss=0.0191 val_loss=0.0308 train_acc=0.9938 val_acc=0.9928
# Epoch 16: train_loss=0.0189 val_loss=0.0352 train_acc=0.9937 val_acc=0.9926
# Epoch 17: train_loss=0.0162 val_loss=0.0338 train_acc=0.9944 val_acc=0.9917
# Epoch 18: train_loss=0.0166 val_loss=0.0311 train_acc=0.9945 val_acc=0.9931
# Epoch 19: train_loss=0.0141 val_loss=0.0389 train_acc=0.9950 val_acc=0.9923
# Epoch 20: train_loss=0.0140 val_loss=0.0360 train_acc=0.9952 val_acc=0.9922
# Custom CNN (adam) Test Accuracy: 0.9901
#               precision    recall  f1-score   support
#
#            0     0.9891    0.9980    0.9935       996
#            1     0.9892    0.9967    0.9929      1197
#            2     0.9904    0.9857    0.9881      1050
#            3     0.9981    0.9858    0.9919      1059
#            4     0.9951    0.9846    0.9899      1041
#            5     0.9874    0.9905    0.9890       950
#            6     0.9933    0.9933    0.9933      1038
#            7     0.9900    0.9918    0.9909      1095
#            8     0.9950    0.9822    0.9885      1010
#            9     0.9741    0.9915    0.9828      1064
#
#     accuracy                         0.9901     10500
#    macro avg     0.9902    0.9900    0.9901     10500
# weighted avg     0.9901    0.9901    0.9901     10500
# ===== Training with SGD =====
# Epoch 01: train_loss=1.0312 val_loss=0.3465 train_acc=0.6910 val_acc=0.8984
# Epoch 02: train_loss=0.3864 val_loss=0.2167 train_acc=0.8831 val_acc=0.9359
# Epoch 03: train_loss=0.2912 val_loss=0.1702 train_acc=0.9136 val_acc=0.9469
# Epoch 04: train_loss=0.2434 val_loss=0.1509 train_acc=0.9272 val_acc=0.9504
# Epoch 05: train_loss=0.2033 val_loss=0.1203 train_acc=0.9394 val_acc=0.9640
# Epoch 06: train_loss=0.1788 val_loss=0.1029 train_acc=0.9461 val_acc=0.9688
# Epoch 07: train_loss=0.1607 val_loss=0.0949 train_acc=0.9524 val_acc=0.9718
# Epoch 08: train_loss=0.1461 val_loss=0.0829 train_acc=0.9568 val_acc=0.9751
# Epoch 09: train_loss=0.1332 val_loss=0.0743 train_acc=0.9601 val_acc=0.9780
# Epoch 10: train_loss=0.1232 val_loss=0.0725 train_acc=0.9628 val_acc=0.9784
# Epoch 11: train_loss=0.1149 val_loss=0.0783 train_acc=0.9659 val_acc=0.9770
# Epoch 12: train_loss=0.1072 val_loss=0.0640 train_acc=0.9676 val_acc=0.9818
# Epoch 13: train_loss=0.1029 val_loss=0.0585 train_acc=0.9693 val_acc=0.9830
# Epoch 14: train_loss=0.0973 val_loss=0.0574 train_acc=0.9700 val_acc=0.9826
# Epoch 15: train_loss=0.0937 val_loss=0.0539 train_acc=0.9725 val_acc=0.9841
# Epoch 16: train_loss=0.0892 val_loss=0.0526 train_acc=0.9736 val_acc=0.9844
# Epoch 17: train_loss=0.0844 val_loss=0.0523 train_acc=0.9745 val_acc=0.9853
# Epoch 18: train_loss=0.0814 val_loss=0.0523 train_acc=0.9757 val_acc=0.9845
# Epoch 19: train_loss=0.0807 val_loss=0.0502 train_acc=0.9755 val_acc=0.9851
# Epoch 20: train_loss=0.0772 val_loss=0.0471 train_acc=0.9761 val_acc=0.9869
# Custom CNN (sgd) Test Accuracy: 0.9841
#               precision    recall  f1-score   support
#
#            0     0.9851    0.9980    0.9915       996
#            1     0.9891    0.9891    0.9891      1197
#            2     0.9801    0.9857    0.9829      1050
#            3     0.9783    0.9811    0.9797      1059
#            4     0.9913    0.9817    0.9865      1041
#            5     0.9873    0.9832    0.9852       950
#            6     0.9923    0.9894    0.9908      1038
#            7     0.9817    0.9817    0.9817      1095
#            8     0.9745    0.9832    0.9788      1010
#            9     0.9810    0.9680    0.9745      1064
#
#     accuracy                         0.9841     10500
#    macro avg     0.9841    0.9841    0.9841     10500
# weighted avg     0.9841    0.9841    0.9841     10500
# ===== Training with SGD_MOM =====
# Epoch 01: train_loss=0.4564 val_loss=0.1046 train_acc=0.8574 val_acc=0.9694
# Epoch 02: train_loss=0.1302 val_loss=0.0599 train_acc=0.9612 val_acc=0.9811
# Epoch 03: train_loss=0.0922 val_loss=0.0476 train_acc=0.9729 val_acc=0.9854
# Epoch 04: train_loss=0.0767 val_loss=0.0464 train_acc=0.9774 val_acc=0.9857
# Epoch 05: train_loss=0.0624 val_loss=0.0357 train_acc=0.9811 val_acc=0.9892
# Epoch 06: train_loss=0.0572 val_loss=0.0360 train_acc=0.9823 val_acc=0.9891
# Epoch 07: train_loss=0.0490 val_loss=0.0371 train_acc=0.9854 val_acc=0.9891
# Epoch 08: train_loss=0.0463 val_loss=0.0357 train_acc=0.9859 val_acc=0.9888
# Epoch 09: train_loss=0.0420 val_loss=0.0352 train_acc=0.9866 val_acc=0.9896
# Epoch 10: train_loss=0.0369 val_loss=0.0314 train_acc=0.9886 val_acc=0.9919
# Epoch 11: train_loss=0.0348 val_loss=0.0302 train_acc=0.9891 val_acc=0.9910
# Epoch 12: train_loss=0.0313 val_loss=0.0309 train_acc=0.9900 val_acc=0.9911
# Epoch 13: train_loss=0.0301 val_loss=0.0308 train_acc=0.9906 val_acc=0.9914
# Epoch 14: train_loss=0.0280 val_loss=0.0316 train_acc=0.9909 val_acc=0.9909
# Epoch 15: train_loss=0.0264 val_loss=0.0297 train_acc=0.9919 val_acc=0.9913
# Epoch 16: train_loss=0.0244 val_loss=0.0274 train_acc=0.9921 val_acc=0.9913
# Epoch 17: train_loss=0.0232 val_loss=0.0303 train_acc=0.9926 val_acc=0.9922
# Epoch 18: train_loss=0.0219 val_loss=0.0304 train_acc=0.9929 val_acc=0.9917
# Epoch 19: train_loss=0.0186 val_loss=0.0266 train_acc=0.9938 val_acc=0.9927
# Epoch 20: train_loss=0.0192 val_loss=0.0270 train_acc=0.9939 val_acc=0.9923
# Custom CNN (sgd_mom) Test Accuracy: 0.9914
#               precision    recall  f1-score   support
#
#            0     0.9920    0.9970    0.9945       996
#            1     0.9917    0.9958    0.9937      1197
#            2     0.9895    0.9895    0.9895      1050
#            3     0.9924    0.9887    0.9905      1059
#            4     0.9952    0.9894    0.9923      1041
#            5     0.9936    0.9863    0.9900       950
#            6     0.9942    0.9971    0.9957      1038
#            7     0.9927    0.9909    0.9918      1095
#            8     0.9921    0.9901    0.9911      1010
#            9     0.9813    0.9887    0.9850      1064
#
#     accuracy                         0.9914     10500
#    macro avg     0.9915    0.9914    0.9914     10500
# weighted avg     0.9914    0.9914    0.9914     10500
# Optimizer comparison summary:
#   optimizer  accuracy
# 0      adam  0.990095
# 1       sgd  0.984095
# 2   sgd_mom  0.991429
#
# === Fine-tuning VGG16 ===
# Downloading: "https://download.pytorch.org/models/vgg16-397923af.pth" to /root/.cache/torch/hub/checkpoints/vgg16-397923af.pth
# 100%|██████████| 528M/528M [00:05<00:00, 97.6MB/s]

# %%
import torch, torch.nn as nn, torch.nn.functional as F, torch.optim as optim
from torch.utils.data import random_split, DataLoader, Subset
from torchvision import datasets, transforms, models
import matplotlib.pyplot as plt
import numpy as np, pandas as pd, seaborn as sns, os
from sklearn.metrics import confusion_matrix, classification_report


transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.1307,), (0.3081,))
])
# Transfer Learning: VGG16 and ResNet50
# Resize MNIST to 224x224x3 for pretrained models
resize_tf = transforms.Compose([
    transforms.Resize((224,224)),
    transforms.Grayscale(num_output_channels=3),
    transforms.ToTensor(),
    transforms.Normalize((0.5,0.5,0.5),(0.5,0.5,0.5))
])
mnist_train_tl = datasets.MNIST(root="./data", train=True, download=True, transform=resize_tf)
mnist_test_tl  = datasets.MNIST(root="./data", train=False, download=True, transform=resize_tf)

subset_size = 10000
train_subset = Subset(mnist_train_tl, range(0, int(subset_size * 0.7)))
val_subset = Subset(mnist_train_tl, range(int(subset_size * 0.7), subset_size))
test_subset = Subset(mnist_test_tl, range(0, int(subset_size * 0.15)))

print(f"Transfer Learning Dataset Sizes:")
print(f"  Train: {len(train_subset)}")
print(f"  Val: {len(val_subset)}")
print(f"  Test: {len(test_subset)}")

train_loader_tl = DataLoader(train_subset, batch_size=32, shuffle=True)
val_loader_tl   = DataLoader(val_subset, batch_size=32, shuffle=False)
test_loader_tl  = DataLoader(test_subset, batch_size=32, shuffle=False)

def evaluate_model(model, loader, criterion, name="Model"):
    model.eval()
    preds, labels = [], []
    total_loss=0
    with torch.no_grad():
        for x,y in loader:
            out=model(x)
            total_loss+=criterion(out,y).item()
            preds.extend(out.argmax(1).numpy())
            labels.extend(y.numpy())
    avg_loss = total_loss/len(loader)
    acc = np.mean(np.array(preds)==np.array(labels))
    print(f"\n{name} Test Accuracy: {acc:.4f}")
    print(classification_report(labels, preds, digits=4))
    cm = confusion_matrix(labels,preds)
    sns.heatmap(cm,annot=True,fmt="d"); plt.title(f"{name} Confusion Matrix"); plt.show()
    return acc, cm, labels, preds

def build_finetune_model(base="vgg16"):
    if base=="vgg16":
        net=models.vgg16(weights="IMAGENET1K_V1")
        for param in net.features.parameters(): param.requires_grad=False
        net.classifier[-1]=nn.Linear(4096,10)
    elif base=="resnet50":
        net=models.resnet50(weights="IMAGENET1K_V1")
        for param in list(net.parameters())[:-20]: param.requires_grad=False
        net.fc=nn.Linear(net.fc.in_features,10)
    return net

def train_tl_model(model, train_loader, val_loader, epochs=5):
    # fewer epochs since heavy network
    optimizer=optim.Adam(model.parameters(),lr=1e-4)
    criterion=nn.CrossEntropyLoss()
    best_acc=0
    for ep in range(epochs):
        model.train(); running_loss=0; correct=0; total=0
        for x,y in train_loader:
            optimizer.zero_grad(); out=model(x)
            loss=criterion(out,y); loss.backward(); optimizer.step()
            running_loss+=loss.item(); correct+=(out.argmax(1)==y).sum().item(); total+=y.size(0)
        train_acc=correct/total
        # val
        model.eval(); v_correct=0; v_total=0; v_loss=0
        with torch.no_grad():
            for x,y in val_loader:
                out=model(x)
                v_loss+=criterion(out,y).item()
                v_correct+=(out.argmax(1)==y).sum().item(); v_total+=y.size(0)
        val_acc=v_correct/v_total
        print(f"Epoch {ep+1}: train_acc={train_acc:.4f} val_acc={val_acc:.4f}")
    return model

results = []
for base in ["vgg16","resnet50"]:
    print(f"\n=== Fine-tuning {base.upper()} ===")
    model_tl=build_finetune_model(base)
    model_tl=train_tl_model(model_tl,train_loader_tl,val_loader_tl,epochs=5)
    acc,cm,_,_=evaluate_model(model_tl,test_loader_tl,nn.CrossEntropyLoss(),name=f"{base.upper()} fine-tuned")
    results.append({'optimizer':base,'accuracy':acc})

# Final summary
print("\nFinal Model Accuracies:")
df=pd.DataFrame(results)
print(df)
sns.barplot(data=df,x='optimizer',y='accuracy')
plt.title("Final Model Test Accuracies")
plt.show()
# Out:
# Transfer Learning Dataset Sizes:
#   Train: 7000
#   Val: 3000
#   Test: 1500
#
# === Fine-tuning VGG16 ===
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-463301768.py in <cell line: 0>()
#      92     print(f"\n=== Fine-tuning {base.upper()} ===")
#      93     model_tl=build_finetune_model(base)
# ---> 94     model_tl=train_tl_model(model_tl,train_loader_tl,val_loader_tl,epochs=5)
#      95     acc,cm,_,_=evaluate_model(model_tl,test_loader_tl,nn.CrossEntropyLoss(),name=f"{base.upper()} fine-tuned")
#      96     results.append({'optimizer':base,'accuracy':acc})
#
# /tmp/ipython-input-463301768.py in train_tl_model(model, train_loader, val_loader, epochs)
#      73         model.train(); running_loss=0; correct=0; total=0
#      74         for x,y in train_loader:
# ---> 75             optimizer.zero_grad(); out=model(x)
#      76             loss=criterion(out,y); loss.backward(); optimizer.step()
#      77             running_loss+=loss.item(); correct+=(out.argmax(1)==y).sum().item(); total+=y.size(0)
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1771             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772         else:
# -> 1773             return self._call_impl(*args, **kwargs)
#    1774
#    1775     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1782                 or _global_backward_pre_hooks or _global_backward_hooks
#    1783                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784             return forward_call(*args, **kwargs)
#    1785
#    1786         result = None
#
# /usr/local/lib/python3.12/dist-packages/torchvision/models/vgg.py in forward(self, x)
#      64
#      65     def forward(self, x: torch.Tensor) -> torch.Tensor:
# ---> 66         x = self.features(x)
#      67         x = self.avgpool(x)
#      68         x = torch.flatten(x, 1)
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1771             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772         else:
# -> 1773             return self._call_impl(*args, **kwargs)
#    1774
#    1775     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1782                 or _global_backward_pre_hooks or _global_backward_hooks
#    1783                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784             return forward_call(*args, **kwargs)
#    1785
#    1786         result = None
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/container.py in forward(self, input)
#     242     def forward(self, input):
#     243         for module in self:
# --> 244             input = module(input)
#     245         return input
#     246
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1771             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772         else:
# -> 1773             return self._call_impl(*args, **kwargs)
#    1774
#    1775     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1782                 or _global_backward_pre_hooks or _global_backward_hooks
#    1783                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784             return forward_call(*args, **kwargs)
#    1785
#    1786         result = None
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/conv.py in forward(self, input)
#     546
#     547     def forward(self, input: Tensor) -> Tensor:
# --> 548         return self._conv_forward(input, self.weight, self.bias)
#     549
#     550
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/conv.py in _conv_forward(self, input, weight, bias)
#     541                 self.groups,
#     542             )
# --> 543         return F.conv2d(
#     544             input, weight, bias, self.stride, self.padding, self.dilation, self.groups
#     545         )
#
# KeyboardInterrupt:

# %%
import torch, torch.nn as nn, torch.nn.functional as F, torch.optim as optim
from torch.utils.data import random_split, DataLoader, Subset
from torchvision import datasets, transforms, models
import matplotlib.pyplot as plt
import numpy as np, pandas as pd, seaborn as sns, os
from sklearn.metrics import confusion_matrix, classification_report


transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.1307,), (0.3081,))
])

# Transfer Learning: VGG16 and ResNet50
# Resize MNIST to 224x224x3 for pretrained models
resize_tf = transforms.Compose([
    transforms.Resize((96,96)),
    transforms.Grayscale(num_output_channels=3),
    transforms.ToTensor(),
    transforms.Normalize((0.5,0.5,0.5),(0.5,0.5,0.5))
])
mnist_train_tl = datasets.MNIST(root="./data", train=True, download=True, transform=resize_tf)
mnist_test_tl  = datasets.MNIST(root="./data", train=False, download=True, transform=resize_tf)

full_tl = torch.utils.data.ConcatDataset([mnist_train_tl,mnist_test_tl])
subset_size = 10000
subset_tl, _ = random_split(full_tl, [subset_size, len(full_tl)- subset_size])

n_train=int(0.70*subset_size); n_val=int(0.15*subset_size); n_test=subset_size-n_train-n_val

train_tl,val_tl,test_tl = random_split(subset_tl,[n_train,n_val,n_test])

train_loader_tl = DataLoader(train_tl,batch_size=64,shuffle=True)
val_loader_tl   = DataLoader(val_tl,batch_size=64,shuffle=False)
test_loader_tl  = DataLoader(test_tl,batch_size=64,shuffle=False)

def build_finetune_model(base="vgg16"):
    if base=="vgg16":
        net=models.vgg16(weights="IMAGENET1K_V1")
        for param in net.features.parameters(): param.requires_grad=False
        net.classifier[-1]=nn.Linear(4096,10)
    elif base=="resnet50":
        net=models.resnet50(weights="IMAGENET1K_V1")
        for param in list(net.parameters())[:-20]: param.requires_grad=False
        net.fc=nn.Linear(net.fc.in_features,10)
    return net

def train_tl_model(model, train_loader, val_loader, epochs=5):
    # fewer epochs since heavy network
    optimizer=optim.Adam(model.parameters(),lr=1e-4)
    criterion=nn.CrossEntropyLoss()
    best_acc=0
    for ep in range(epochs):
        model.train(); running_loss=0; correct=0; total=0
        for x,y in train_loader:
            optimizer.zero_grad(); out=model(x)
            loss=criterion(out,y); loss.backward(); optimizer.step()
            running_loss+=loss.item(); correct+=(out.argmax(1)==y).sum().item(); total+=y.size(0)
        train_acc=correct/total
        # val
        model.eval(); v_correct=0; v_total=0; v_loss=0
        with torch.no_grad():
            for x,y in val_loader:
                out=model(x)
                v_loss+=criterion(out,y).item()
                v_correct+=(out.argmax(1)==y).sum().item(); v_total+=y.size(0)
        val_acc=v_correct/v_total
        print(f"Epoch {ep+1}: train_acc={train_acc:.4f} val_acc={val_acc:.4f}")
    return model

for base in ["vgg16","resnet50"]:
    print(f"\n=== Fine-tuning {base.upper()} ===")
    model_tl=build_finetune_model(base)
    model_tl=train_tl_model(model_tl,train_loader_tl,val_loader_tl,epochs=5)
    acc,cm,_,_=evaluate_model(model_tl,test_loader_tl,nn.CrossEntropyLoss(),name=f"{base.upper()} fine-tuned")
    results.append({'optimizer':base,'accuracy':acc})

# Final summary
print("\nFinal Model Accuracies:")
df=pd.DataFrame(results)
print(df)
sns.barplot(data=df,x='optimizer',y='accuracy')
plt.title("Final Model Test Accuracies")
plt.show()
# Out:
# === Fine-tuning VGG16 ===
