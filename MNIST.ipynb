# %% [markdown]
# <a href="https://colab.research.google.com/github/PiumiOshani/EN3150_CNN_Project/blob/main/MNIST.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch, torch.nn as nn, torch.nn.functional as F, torch.optim as optim
from torch.utils.data import random_split, DataLoader, Subset
from torchvision import datasets, transforms, models
import matplotlib.pyplot as plt
import numpy as np, pandas as pd, seaborn as sns, os
from sklearn.metrics import confusion_matrix, classification_report, precision_score, recall_score

transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.1307,), (0.3081,))
])
mnist_train_full = datasets.MNIST(root="./data", train=True, download=True, transform=transform)
mnist_test_full  = datasets.MNIST(root="./data", train=False, download=True, transform=transform)

# Combine train + test then re-split 70/15/15
full_dataset = torch.utils.data.ConcatDataset([mnist_train_full, mnist_test_full])
n_total = len(full_dataset)
n_train = int(0.70 * n_total)
n_val   = int(0.15 * n_total)
n_test  = n_total - n_train - n_val
train_set, val_set, test_set = random_split(full_dataset, [n_train, n_val, n_test])

batch_size = 128
train_loader = DataLoader(train_set, batch_size=batch_size, shuffle=True)
val_loader   = DataLoader(val_set, batch_size=batch_size, shuffle=False)
test_loader  = DataLoader(test_set, batch_size=batch_size, shuffle=False)

# Define Custom CNN
class SimpleCNN(nn.Module):
    def __init__(self):
        super(SimpleCNN, self).__init__()
        self.conv1 = nn.Conv2d(1, 32, 3, padding=1)
        self.conv2 = nn.Conv2d(32, 64, 3, padding=1)
        self.pool  = nn.MaxPool2d(2,2)
        self.fc1   = nn.Linear(64*7*7, 128)
        self.drop  = nn.Dropout(0.25)
        self.fc2   = nn.Linear(128, 10)
    def forward(self, x):
        x = F.relu(self.conv1(x))
        x = self.pool(F.relu(self.conv2(x)))
        x = self.pool(x)
        x = x.view(-1, 64*7*7)
        x = F.relu(self.fc1(x))
        x = self.drop(x)
        x = self.fc2(x)
        return x

# Training utilities
def train_model(model, optimizer, criterion, train_loader, val_loader, epochs=20):
    history = {'train_loss':[], 'val_loss':[], 'train_acc':[], 'val_acc':[]}
    for ep in range(epochs):
        model.train()
        correct, total, running_loss = 0,0,0
        for x, y in train_loader:
            optimizer.zero_grad()
            out = model(x)
            loss = criterion(out,y)
            loss.backward()
            optimizer.step()
            running_loss += loss.item()
            pred = out.argmax(1)
            correct += (pred==y).sum().item(); total += y.size(0)
        train_loss = running_loss/len(train_loader)
        train_acc  = correct/total
        # validation
        model.eval(); v_correct,v_total,v_loss=0,0,0
        with torch.no_grad():
            for x,y in val_loader:
                out = model(x)
                loss = criterion(out,y)
                v_loss += loss.item()
                pred = out.argmax(1)
                v_correct += (pred==y).sum().item(); v_total += y.size(0)
        val_loss = v_loss/len(val_loader); val_acc = v_correct/v_total
        history['train_loss'].append(train_loss)
        history['val_loss'].append(val_loss)
        history['train_acc'].append(train_acc)
        history['val_acc'].append(val_acc)
        print(f"Epoch {ep+1:02d}: train_loss={train_loss:.4f} val_loss={val_loss:.4f} train_acc={train_acc:.4f} val_acc={val_acc:.4f}")
    return history

  # Evaluation utilities
def evaluate_model(model, loader, criterion, name="Model"):
    model.eval()
    preds, labels = [], []
    total_loss=0
    with torch.no_grad():
        for x,y in loader:
            out=model(x)
            total_loss+=criterion(out,y).item()
            preds.extend(out.argmax(1).numpy())
            labels.extend(y.numpy())
    avg_loss = total_loss/len(loader)
    acc = np.mean(np.array(preds)==np.array(labels))
    print(f"\n{name} Test Accuracy: {acc:.4f}")
    print(classification_report(labels, preds, digits=4))
    cm = confusion_matrix(labels,preds)
    sns.heatmap(cm,annot=True,fmt="d"); plt.title(f"{name} Confusion Matrix"); plt.show()
    return acc, cm, labels, preds

def plot_history(hist, title):
    plt.figure(figsize=(12,4))
    plt.subplot(1,2,1); plt.plot(hist['train_loss'],label='train'); plt.plot(hist['val_loss'],label='val'); plt.title(title+" Loss"); plt.legend()
    plt.subplot(1,2,2); plt.plot(hist['train_acc'],label='train'); plt.plot(hist['val_acc'],label='val'); plt.title(title+" Accuracy"); plt.legend()
    plt.show()

# Train Custom CNN with Adam, SGD, SGD+Momentum
criterion = nn.CrossEntropyLoss()
optimizers_cfg = {
    'adam': lambda m: optim.Adam(m.parameters(), lr=1e-3),
    'sgd':  lambda m: optim.SGD(m.parameters(), lr=0.01),
    'sgd_mom': lambda m: optim.SGD(m.parameters(), lr=0.01, momentum=0.9)
}

results=[]
for name,opt_fn in optimizers_cfg.items():
    print(f"\n===== Training with {name.upper()} =====")
    model = SimpleCNN()
    optimizer = opt_fn(model)
    hist = train_model(model, optimizer, criterion, train_loader, val_loader, epochs=20)
    plot_history(hist, f"Custom CNN ({name})")
    acc,cm,ytrue,ypred = evaluate_model(model, test_loader, criterion, name=f"Custom CNN ({name})")
    results.append({'optimizer':name,'accuracy':acc})

print("\nOptimizer comparison summary:")
print(pd.DataFrame(results))
# Out:
# ===== Training with ADAM =====
# Epoch 01: train_loss=0.2149 val_loss=0.0511 train_acc=0.9336 val_acc=0.9846
# Epoch 02: train_loss=0.0586 val_loss=0.0374 train_acc=0.9818 val_acc=0.9889
# Epoch 03: train_loss=0.0426 val_loss=0.0328 train_acc=0.9864 val_acc=0.9894
# Epoch 04: train_loss=0.0338 val_loss=0.0325 train_acc=0.9895 val_acc=0.9903
# Epoch 05: train_loss=0.0279 val_loss=0.0294 train_acc=0.9910 val_acc=0.9912
# Epoch 06: train_loss=0.0226 val_loss=0.0304 train_acc=0.9924 val_acc=0.9906
# Epoch 07: train_loss=0.0194 val_loss=0.0314 train_acc=0.9938 val_acc=0.9907
# Epoch 08: train_loss=0.0162 val_loss=0.0307 train_acc=0.9947 val_acc=0.9906
# Epoch 09: train_loss=0.0154 val_loss=0.0335 train_acc=0.9949 val_acc=0.9911
# Epoch 10: train_loss=0.0151 val_loss=0.0272 train_acc=0.9949 val_acc=0.9931
# Epoch 11: train_loss=0.0126 val_loss=0.0344 train_acc=0.9957 val_acc=0.9916
# Epoch 12: train_loss=0.0112 val_loss=0.0280 train_acc=0.9961 val_acc=0.9922
# Epoch 13: train_loss=0.0101 val_loss=0.0319 train_acc=0.9966 val_acc=0.9927
# Epoch 14: train_loss=0.0095 val_loss=0.0337 train_acc=0.9968 val_acc=0.9918
# Epoch 15: train_loss=0.0095 val_loss=0.0321 train_acc=0.9966 val_acc=0.9925
# Epoch 16: train_loss=0.0065 val_loss=0.0348 train_acc=0.9978 val_acc=0.9927
# Epoch 17: train_loss=0.0088 val_loss=0.0314 train_acc=0.9971 val_acc=0.9923
# Epoch 18: train_loss=0.0085 val_loss=0.0304 train_acc=0.9969 val_acc=0.9931
# Epoch 19: train_loss=0.0069 val_loss=0.0310 train_acc=0.9979 val_acc=0.9928
# Epoch 20: train_loss=0.0053 val_loss=0.0385 train_acc=0.9981 val_acc=0.9926
# Custom CNN (adam) Test Accuracy: 0.9923
#               precision    recall  f1-score   support
#
#            0     0.9934    0.9962    0.9948      1062
#            1     0.9951    0.9967    0.9959      1214
#            2     0.9941    0.9922    0.9931      1022
#            3     0.9962    0.9897    0.9930      1073
#            4     0.9904    0.9971    0.9937      1036
#            5     0.9914    0.9924    0.9919       926
#            6     0.9933    0.9933    0.9933      1042
#            7     0.9916    0.9906    0.9911      1067
#            8     0.9893    0.9855    0.9874      1034
#            9     0.9873    0.9883    0.9878      1024
#
#     accuracy                         0.9923     10500
#    macro avg     0.9922    0.9922    0.9922     10500
# weighted avg     0.9923    0.9923    0.9923     10500
# ===== Training with SGD =====
# Epoch 01: train_loss=0.9846 val_loss=0.3306 train_acc=0.7255 val_acc=0.9054
# Epoch 02: train_loss=0.3132 val_loss=0.2030 train_acc=0.9053 val_acc=0.9422
# Epoch 03: train_loss=0.2125 val_loss=0.1498 train_acc=0.9356 val_acc=0.9557
# Epoch 04: train_loss=0.1611 val_loss=0.1191 train_acc=0.9521 val_acc=0.9643
# Epoch 05: train_loss=0.1337 val_loss=0.0990 train_acc=0.9599 val_acc=0.9703
# Epoch 06: train_loss=0.1153 val_loss=0.0862 train_acc=0.9657 val_acc=0.9735
# Epoch 07: train_loss=0.1012 val_loss=0.0775 train_acc=0.9698 val_acc=0.9770
# Epoch 08: train_loss=0.0909 val_loss=0.0704 train_acc=0.9725 val_acc=0.9786
# Epoch 09: train_loss=0.0845 val_loss=0.0697 train_acc=0.9746 val_acc=0.9785
# Epoch 10: train_loss=0.0790 val_loss=0.0623 train_acc=0.9753 val_acc=0.9814
# Epoch 11: train_loss=0.0735 val_loss=0.0581 train_acc=0.9782 val_acc=0.9822
# Epoch 12: train_loss=0.0687 val_loss=0.0599 train_acc=0.9793 val_acc=0.9808
# Epoch 13: train_loss=0.0625 val_loss=0.0569 train_acc=0.9811 val_acc=0.9825
# Epoch 14: train_loss=0.0610 val_loss=0.0506 train_acc=0.9818 val_acc=0.9839
# Epoch 15: train_loss=0.0573 val_loss=0.0493 train_acc=0.9826 val_acc=0.9845
# Epoch 16: train_loss=0.0544 val_loss=0.0475 train_acc=0.9830 val_acc=0.9853
# Epoch 17: train_loss=0.0528 val_loss=0.0541 train_acc=0.9841 val_acc=0.9827
# Epoch 18: train_loss=0.0517 val_loss=0.0445 train_acc=0.9839 val_acc=0.9861
# Epoch 19: train_loss=0.0488 val_loss=0.0449 train_acc=0.9847 val_acc=0.9857
# Epoch 20: train_loss=0.0466 val_loss=0.0447 train_acc=0.9855 val_acc=0.9855
# Custom CNN (sgd) Test Accuracy: 0.9840
#               precision    recall  f1-score   support
#
#            0     0.9869    0.9896    0.9882      1062
#            1     0.9926    0.9893    0.9909      1214
#            2     0.9704    0.9932    0.9816      1022
#            3     0.9943    0.9767    0.9854      1073
#            4     0.9782    0.9942    0.9861      1036
#            5     0.9859    0.9838    0.9849       926
#            6     0.9875    0.9885    0.9880      1042
#            7     0.9868    0.9803    0.9835      1067
#            8     0.9756    0.9681    0.9718      1034
#            9     0.9804    0.9756    0.9780      1024
#
#     accuracy                         0.9840     10500
#    macro avg     0.9839    0.9839    0.9839     10500
# weighted avg     0.9841    0.9840    0.9840     10500
# ===== Training with SGD_MOM =====
# Epoch 01: train_loss=0.3918 val_loss=0.0893 train_acc=0.8780 val_acc=0.9725
# Epoch 02: train_loss=0.0984 val_loss=0.0556 train_acc=0.9699 val_acc=0.9829
# Epoch 03: train_loss=0.0704 val_loss=0.0450 train_acc=0.9783 val_acc=0.9861
# Epoch 04: train_loss=0.0554 val_loss=0.0420 train_acc=0.9826 val_acc=0.9869
# Epoch 05: train_loss=0.0453 val_loss=0.0382 train_acc=0.9859 val_acc=0.9876
# Epoch 06: train_loss=0.0418 val_loss=0.0335 train_acc=0.9868 val_acc=0.9901
# Epoch 07: train_loss=0.0348 val_loss=0.0336 train_acc=0.9889 val_acc=0.9897
# Epoch 08: train_loss=0.0305 val_loss=0.0330 train_acc=0.9904 val_acc=0.9894
# Epoch 09: train_loss=0.0279 val_loss=0.0320 train_acc=0.9910 val_acc=0.9894
# Epoch 10: train_loss=0.0244 val_loss=0.0327 train_acc=0.9916 val_acc=0.9910
# Epoch 11: train_loss=0.0223 val_loss=0.0304 train_acc=0.9928 val_acc=0.9910
# Epoch 12: train_loss=0.0219 val_loss=0.0344 train_acc=0.9927 val_acc=0.9907
# Epoch 13: train_loss=0.0189 val_loss=0.0321 train_acc=0.9937 val_acc=0.9900
# Epoch 14: train_loss=0.0184 val_loss=0.0337 train_acc=0.9939 val_acc=0.9914
# Epoch 15: train_loss=0.0161 val_loss=0.0329 train_acc=0.9948 val_acc=0.9902
# Epoch 16: train_loss=0.0133 val_loss=0.0323 train_acc=0.9956 val_acc=0.9908
# Epoch 17: train_loss=0.0143 val_loss=0.0314 train_acc=0.9951 val_acc=0.9914
# Epoch 18: train_loss=0.0122 val_loss=0.0283 train_acc=0.9960 val_acc=0.9917
# Epoch 19: train_loss=0.0112 val_loss=0.0301 train_acc=0.9962 val_acc=0.9922
# Epoch 20: train_loss=0.0110 val_loss=0.0318 train_acc=0.9963 val_acc=0.9913
# Custom CNN (sgd_mom) Test Accuracy: 0.9896
#               precision    recall  f1-score   support
#
#            0     0.9925    0.9925    0.9925      1062
#            1     0.9934    0.9951    0.9942      1214
#            2     0.9835    0.9932    0.9883      1022
#            3     0.9925    0.9925    0.9925      1073
#            4     0.9894    0.9952    0.9923      1036
#            5     0.9924    0.9860    0.9892       926
#            6     0.9839    0.9962    0.9900      1042
#            7     0.9860    0.9878    0.9869      1067
#            8     0.9892    0.9749    0.9820      1034
#            9     0.9931    0.9814    0.9872      1024
#
#     accuracy                         0.9896     10500
#    macro avg     0.9896    0.9895    0.9895     10500
# weighted avg     0.9896    0.9896    0.9896     10500
# Optimizer comparison summary:
#   optimizer  accuracy
# 0      adam  0.992286
# 1       sgd  0.984000
# 2   sgd_mom  0.989619

# %%
# Transfer Learning: VGG16 and ResNet50
# Resize MNIST to 224x224x3 for pretrained models
resize_tf = transforms.Compose([
    transforms.Resize((224,224)),
    transforms.Grayscale(num_output_channels=3),
    transforms.ToTensor(),
    transforms.Normalize((0.5,0.5,0.5),(0.5,0.5,0.5))
])
mnist_train_tl = datasets.MNIST(root="./data", train=True, download=True, transform=resize_tf)
mnist_test_tl  = datasets.MNIST(root="./data", train=False, download=True, transform=resize_tf)
full_tl = torch.utils.data.ConcatDataset([mnist_train_tl,mnist_test_tl])
n_train=int(0.70*len(full_tl)); n_val=int(0.15*len(full_tl)); n_test=len(full_tl)-n_train-n_val
train_tl,val_tl,test_tl = random_split(full_tl,[n_train,n_val,n_test])
train_loader_tl = DataLoader(train_tl,batch_size=64,shuffle=True)
val_loader_tl   = DataLoader(val_tl,batch_size=64,shuffle=False)
test_loader_tl  = DataLoader(test_tl,batch_size=64,shuffle=False)

def build_finetune_model(base="vgg16"):
    if base=="vgg16":
        net=models.vgg16(weights="IMAGENET1K_V1")
        for param in net.features.parameters(): param.requires_grad=False
        net.classifier[-1]=nn.Linear(4096,10)
    elif base=="resnet50":
        net=models.resnet50(weights="IMAGENET1K_V1")
        for param in list(net.parameters())[:-20]: param.requires_grad=False
        net.fc=nn.Linear(net.fc.in_features,10)
    return net

def train_tl_model(model, train_loader, val_loader, epochs=5):
    # fewer epochs since heavy network
    optimizer=optim.Adam(model.parameters(),lr=1e-4)
    criterion=nn.CrossEntropyLoss()
    best_acc=0
    for ep in range(epochs):
        model.train(); running_loss=0; correct=0; total=0
        for x,y in train_loader:
            optimizer.zero_grad(); out=model(x)
            loss=criterion(out,y); loss.backward(); optimizer.step()
            running_loss+=loss.item(); correct+=(out.argmax(1)==y).sum().item(); total+=y.size(0)
        train_acc=correct/total
        # val
        model.eval(); v_correct=0; v_total=0; v_loss=0
        with torch.no_grad():
            for x,y in val_loader:
                out=model(x)
                v_loss+=criterion(out,y).item()
                v_correct+=(out.argmax(1)==y).sum().item(); v_total+=y.size(0)
        val_acc=v_correct/v_total
        print(f"Epoch {ep+1}: train_acc={train_acc:.4f} val_acc={val_acc:.4f}")
    return model

for base in ["vgg16","resnet50"]:
    print(f"\n=== Fine-tuning {base.upper()} ===")
    model_tl=build_finetune_model(base)
    model_tl=train_tl_model(model_tl,train_loader_tl,val_loader_tl,epochs=5)
    acc,cm,_,_=evaluate_model(model_tl,test_loader_tl,nn.CrossEntropyLoss(),name=f"{base.upper()} fine-tuned")
    results.append({'optimizer':base,'accuracy':acc})

# Final summary
print("\nFinal Model Accuracies:")
df=pd.DataFrame(results)
print(df)
sns.barplot(data=df,x='optimizer',y='accuracy')
plt.title("Final Model Test Accuracies")
plt.show()
# Out:
# === Fine-tuning VGG16 ===
# Downloading: "https://download.pytorch.org/models/vgg16-397923af.pth" to /root/.cache/torch/hub/checkpoints/vgg16-397923af.pth
# 100%|██████████| 528M/528M [00:07<00:00, 72.4MB/s]
